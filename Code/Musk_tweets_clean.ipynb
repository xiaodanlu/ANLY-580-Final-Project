# %%
import pandas as pd
import os
import time
import requests
import json
import csv
from tqdm import tqdm
import html
import tweepy
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import numpy

# %% [markdown]
# Open Dataset

# %%
data = pd.read_csv("/Users/xiaodanlu/ANLY-580-Final-Project/Data/TweetsElonMusk.csv", encoding='utf-8')
data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12563 entries, 0 to 12562
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               12563 non-null  object
#  1   conversation_id  12563 non-null  float64
#  2   created_at       12562 non-null  object
#  3   date             12562 non-null  object
#  4   time             12562 non-null  object
#  5   timezone         12562 non-null  float64
#  6   user_id          12562 non-null  float64
#  7   username         12562 non-null  object
#  8   name             12562 non-null  object
#  9   place            0 non-null      float64
#  10  tweet            12562 non-null  object
#  11  language         12562 non-null  object
#  12  mentions         12562 non-null  object
#  13  urls             12562 non-null  object
#  14  photos           12562 non-null  object
#  15  replies_count    12562 non-null  float64
#  16  retweets_count   12562 non-null  float64
#  17  likes_count      12562 non-null  float64
#  18  hashtags         12562 non-null  object
#  19  cashtags         12562 non-null  object
#  20  link             12562 non-null  object
#  21  retweet          12562 non-null  object
#  22  quote_url        410 non-null    object
#  23  video            12562 non-null  float64
#  24  thumbnail        792 non-null    object
#  25  near             0 non-null      float64
#  26  geo              0 non-null      float64
#  27  source           0 non-null      float64
#  28  user_rt_id       0 non-null      float64
#  29  user_rt          0 non-null      float64
#  30  retweet_id       0 non-null      float64
#  31  reply_to         12562 non-null  object
#  32  retweet_date     0 non-null      float64
#  33  translate        0 non-null      float64
#  34  trans_src        0 non-null      float64
#  35  trans_dest       1 non-null      float64
# dtypes: float64(18), object(18)
# memory usage: 3.5+ MB
#                 id  conversation_id                created_at     date  \
# 0      1.38127E+18     1.381000e+18  2021-04-11 18:50:33 EEST  4/11/21
# 1      1.38127E+18     1.372440e+18  2021-04-11 18:48:58 EEST  4/11/21
# 2      1.38126E+18     1.381230e+18  2021-04-11 17:49:38 EEST  4/11/21
# 3      1.38122E+18     1.381220e+18  2021-04-11 15:23:49 EEST  4/11/21
# 4      1.38113E+18     1.381080e+18  2021-04-11 09:18:47 EEST  4/11/21
# ...            ...              ...                       ...      ...
# 12558  1.38224E+18     1.382190e+18  2021-04-14 10:50:45 EEST  4/14/21
# 12559  1.38224E+18     1.382190e+18  2021-04-14 10:48:25 EEST  4/14/21
# 12560  1.38213E+18     1.382050e+18  2021-04-14 03:41:45 EEST  4/14/21
# 12561  1.38205E+18     1.382050e+18  2021-04-13 22:25:11 EEST  4/13/21
# 12562        Total     1.256200e+04                       NaN      NaN
#
#            time  timezone     user_id  username       name  place  ... geo  \
# 0      18:50:33     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# 1      18:48:58     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# 2      17:49:38     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# 3      15:23:49     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# 4       9:18:47     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# ...         ...       ...         ...       ...        ...    ...  ...  ..
# 12558  10:50:45     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# 12559  10:48:25     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# 12560   3:41:45     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# 12561  22:25:11     300.0  44196397.0  elonmusk  Elon Musk    NaN  ... NaN
# 12562       NaN       NaN         NaN       NaN        NaN    NaN  ... NaN
#
#       source user_rt_id user_rt retweet_id  \
# 0        NaN        NaN     NaN        NaN
# 1        NaN        NaN     NaN        NaN
# 2        NaN        NaN     NaN        NaN
# 3        NaN        NaN     NaN        NaN
# 4        NaN        NaN     NaN        NaN
# ...      ...        ...     ...        ...
# 12558    NaN        NaN     NaN        NaN
# 12559    NaN        NaN     NaN        NaN
# 12560    NaN        NaN     NaN        NaN
# 12561    NaN        NaN     NaN        NaN
# 12562    NaN        NaN     NaN        NaN
#
#                                                 reply_to  retweet_date  \
# 0      [{'screen_name': 'vincent13031925', 'name': 'V...           NaN
# 1                                                     []           NaN
# 2      [{'screen_name': 'agnostoxxx', 'name': 'Shrubb...           NaN
# 3                                                     []           NaN
# 4      [{'screen_name': 'itsALLrisky', 'name': '💸💸💸',...           NaN
# ...                                                  ...           ...
# 12558  [{'screen_name': 'PPathole', 'name': 'Pranay P...           NaN
# 12559  [{'screen_name': 'PPathole', 'name': 'Pranay P...           NaN
# 12560  [{'screen_name': 'Erdayastronaut', 'name': 'Ev...           NaN
# 12561  [{'screen_name': 'Erdayastronaut', 'name': 'Ev...           NaN
# 12562                                                NaN           NaN
#
#        translate trans_src trans_dest
# 0            NaN       NaN        NaN
# 1            NaN       NaN        NaN
# 2            NaN       NaN        NaN
# 3            NaN       NaN        NaN
# 4            NaN       NaN        NaN
# ...          ...       ...        ...
# 12558        NaN       NaN        NaN
# 12559        NaN       NaN        NaN
# 12560        NaN       NaN        NaN
# 12561        NaN       NaN        NaN
# 12562        NaN       NaN        0.0
#
# [12563 rows x 36 columns]

# %% [markdown]
# Clean Data

# %%
data=data[['date','tweet']]

#delete the duplicates by dropping them
data = data.drop_duplicates("tweet",keep="first")
data.reset_index(inplace=True)
data.drop(columns=['index'],inplace=True)
import re
import string
def clean(text):
    text1 = re.sub(r'#\w+ ?', "", str(text)) #Removes hashtags
    text1 = re.sub(r'@\w+ ?',"",text1) #Removes usernames 
    text1 = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text1) #Removes links 
    text1 = re.sub('[0-9]+', "", text1) #Removes numbers 
    text1 = " ".join(text1.split())
    text1 = "".join([char for char in text1 if char not in string.punctuation]) #Removes punctuations
    text1 = text1.replace('\n',"") #Removes escape sequences
    return text1
data['Tweets_clean'] = data['tweet'].apply(lambda x:clean(x))


stop_words = set(stopwords.words("english"))
def Clean_Words(text):
   text1 = re.split('\W+', text) #Tokenization
   text1 = [word for word in text1 if word not in stop_words] #removing stop words
   text1 = [PorterStemmer().stem(word) for word in text1]#removing suffixes
   text1 = [WordNetLemmatizer().lemmatize(word) for word in text1]#Lemmatization
   return text1

data['Tweets_clean_more'] = data['Tweets_clean'].apply(lambda x:Clean_Words(x))
data
# Out:
#           date                                              tweet  \
# 0      4/11/21  @vincent13031925 For now. Costs are decreasing...
# 1      4/11/21                           Love this beautiful shot
# 2      4/11/21  @agnostoxxx @CathieDWood @ARKInvest Trust the ...
# 3      4/11/21                 The art In Cyberpunk is incredible
# 4      4/11/21                                    @itsALLrisky 🤣🤣
# ...        ...                                                ...
# 12500  4/14/21  @PPathole @SpaceX @Tesla That was my night job...
# 12501  4/14/21  @PPathole @SpaceX @Tesla True. Ancient times …...
# 12502  4/14/21                  @Erdayastronaut @Tesla Absolutely
# 12503  4/13/21  @Erdayastronaut @Tesla Tesla is building up co...
# 12504      NaN                                                NaN
#
#                                             Tweets_clean  \
# 0                   For now Costs are decreasing rapidly
# 1                               Love this beautiful shot
# 2                                        Trust the shrub
# 3                     The art In Cyberpunk is incredible
# 4                                                     🤣🤣
# ...                                                  ...
# 12500  That was my night job Day job was working on r...
# 12501  True Ancient times … Had to flip CPU registers...
# 12502                                         Absolutely
# 12503  Tesla is building up collision repair capabili...
# 12504                                                nan
#
#                                        Tweets_clean_more
# 0                          [for, cost, decreas, rapidli]
# 1                                   [love, beauti, shot]
# 2                                         [trust, shrub]
# 3                      [the, art, in, cyberpunk, incred]
# 4                                                   [, ]
# ...                                                  ...
# 12500  [that, night, job, day, job, work, rutheniumta...
# 12501  [true, ancient, time, had, flip, cpu, regist, ...
# 12502                                          [absolut]
# 12503  [tesla, build, collis, repair, capabl, help, a...
# 12504                                              [nan]
#
# [12505 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12505 entries, 0 to 12504
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               12504 non-null  object
#  1   tweet              12504 non-null  object
#  2   Tweets_clean       12505 non-null  object
#  3   Tweets_clean_more  12505 non-null  object
# dtypes: object(4)
# memory usage: 390.9+ KB

# %%
data['Tweets_clean_more'] = data['Tweets_clean_more'].apply(lambda x:clean(x))
data.head()
# Out:
#       date                                              tweet  \
# 0  4/11/21  @vincent13031925 For now. Costs are decreasing...
# 1  4/11/21                           Love this beautiful shot
# 2  4/11/21  @agnostoxxx @CathieDWood @ARKInvest Trust the ...
# 3  4/11/21                 The art In Cyberpunk is incredible
# 4  4/11/21                                    @itsALLrisky 🤣🤣
#
#                            Tweets_clean            Tweets_clean_more
# 0  For now Costs are decreasing rapidly     for cost decreas rapidli
# 1              Love this beautiful shot             love beauti shot
# 2                       Trust the shrub                  trust shrub
# 3    The art In Cyberpunk is incredible  the art in cyberpunk incred
# 4                                    🤣🤣

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12505 entries, 0 to 12504
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               12504 non-null  object
#  1   tweet              12504 non-null  object
#  2   Tweets_clean       12505 non-null  object
#  3   Tweets_clean_more  12505 non-null  object
# dtypes: object(4)
# memory usage: 390.9+ KB

# %% [markdown]
# Combine tweets with same date

# %%
df=data.groupby('date')['Tweets_clean_more'].apply(' '.join).reset_index()
df.loc[df['date'] =='4/11/21']
# Out:
#          date                                  Tweets_clean_more
# 1048  4/11/21  for cost decreas rapidli love beauti shot trus...

# %%
df.head()
# Out:
#      date                                  Tweets_clean_more
# 0  1/1/12  on lighter note rhcp f awesom no better way br...
# 1  1/1/16  falcon back hangar cape canaver no damag found...
# 2  1/1/19                          congratul team thank haha
# 3  1/1/20  congratul tesla amp spacex great you rock look...
# 4  1/1/21  dojo need make selfdriv better it enough safer...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2034 entries, 0 to 2033
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               2034 non-null   object
#  1   Tweets_clean_more  2034 non-null   object
# dtypes: object(2)
# memory usage: 31.9+ KB

# %%
df = df.loc[df["date"] != '6/4/10']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2033 entries, 0 to 2033
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               2033 non-null   object
#  1   Tweets_clean_more  2033 non-null   object
# dtypes: object(2)
# memory usage: 47.6+ KB

# %% [markdown]
# Sentiment Analysis

# %%
from textblob import TextBlob, Word, Blobber
from textblob.classifiers import NaiveBayesClassifier
from textblob.taggers import NLTKTagger
def get_tweet_sentiment(data): 
    if data > 0: 
        return 'positive'
    elif data == 0: 
        return 'neutral'
    else: 
        return 'negative'
tweets = [TextBlob(tweet) for tweet in df['Tweets_clean_more']]

df['polarity'] = [b.sentiment.polarity for b in tweets]
df['subjectivity'] = [b.sentiment.subjectivity for b in tweets]
df['sentiment'] = df['polarity'].apply(get_tweet_sentiment)
df['sentiment'].value_counts()
# Out:
# positive    1412
# neutral      404
# negative     217
# Name: sentiment, dtype: int64

# %%
df.head()
# Out:
#      date                                  Tweets_clean_more  polarity  \
# 0  1/1/12  on lighter note rhcp f awesom no better way br...  0.232284
# 1  1/1/16  falcon back hangar cape canaver no damag found...  0.000000
# 2  1/1/19                          congratul team thank haha  0.200000
# 3  1/1/20  congratul tesla amp spacex great you rock look...  0.450000
# 4  1/1/21  dojo need make selfdriv better it enough safer...  0.125000
#
#    subjectivity sentiment
# 0      0.423427  positive
# 1      0.000000   neutral
# 2      0.300000  positive
# 3      0.575000  positive
# 4      0.300000  positive

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(7,4))
ax=sns.countplot(data=df,x='sentiment')
ax.set(xlabel='Sentiment',ylabel="Count",title='Count of Different Sentiment')
sns.set(font_scale=1.5)

# %%
from wordcloud import WordCloud
positive=df[df["sentiment"]=="positive"]
plt.rcParams['figure.figsize']=(8,8)
plt.style.use('fast')
wc=WordCloud(background_color='black').generate(str(positive['Tweets_clean_more']))

plt.title('Description Positive', fontsize=15)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
Negative=df[df["sentiment"]=="negative"]
plt.rcParams['figure.figsize']=(8,8)
plt.style.use('fast')
wc=WordCloud(background_color='black').generate(str(Negative['Tweets_clean_more']))

plt.title('Description Negative', fontsize=15)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
neutral=df[df["sentiment"]=="neutral"]
plt.rcParams['figure.figsize']=(8,8)
plt.style.use('fast')
wc=WordCloud(background_color='black').generate(str(neutral['Tweets_clean_more']))

plt.title('Description Neutral', fontsize=15)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
#Save to file
df.to_csv('/Users/xiaodanlu/ANLY-580-Final-Project/Data/TweetsElonMusk_clean.csv',index=False)
